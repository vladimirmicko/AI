# %%
from sklearn import datasets
import random
random.seed(0)
# %matplotlib inline
import sklearn as sk
import numpy as np
import matplotlib.pyplot as plt

digits = datasets.load_digits()
X_digits = digits.data
y_digits = digits.target
print(X_digits.shape)
print(X_digits[0].shape)
ind_all = np.arange(0,len(y_digits))
random.shuffle(ind_all)
ind_training = ind_all[0:int(0.8 * len(ind_all))]
int(0.8 * len(ind_all))
ind_test = ind_all[int(0.8 * len(ind_all)):]
plt.imshow(X_digits[8].reshape(8,8), cmap=plt.cm.gray_r)
# Out:
# (1797, 64)
# (64,)

# %%
import matplotlib.pyplot as plt
import numpy as np
import numpy as np
import random
import sklearn as sk
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from matplotlib import pyplot as plt
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn import datasets

digits = datasets.load_digits()
X_digits = digits.data
y_digits = digits.target

indAll = np.arange(len(y_digits))
np.random.shuffle(indAll)

trainX=X_digits[0:int(0.8*len(indAll))]
testX=X_digits[int(0.8*len(indAll)):]
trainY=y_digits[0:int(0.8*len(indAll))]
testY=y_digits[int(0.8*len(indAll)):]

# lda = LinearDiscriminantAnalysis(n_components=64)
# lda.fit(trainX, trainY)
# ldaPredict = lda.predict(X_digits)
# print(ldaPredict)

# %%
xxx=986
print(y_digits[xxx])
plt.imshow(X_digits[xxx].reshape(8,8))
plt.show()
# Out:
# 2

# %%
xxx=1
print(testY[xxx])
plt.imshow(testX[xxx].reshape(8,8), cmap=plt.cm.gray_r)
plt.show()
# Out:
# 3

# %%
def feature(x):
    y=x.reshape(8,8)
    feature1=sum(y[:,:])
    feature2=sum(feature1)
    print(feature2)
    return feature2

# %%
feature(trainX[4])
# Out:
# 258.0
# 258.0

# %%
trainY.shape
# Out:
# (1437,)

# %%
trainX.shape
# Out:
# (1437, 64)

# %%
lda = LinearDiscriminantAnalysis()
lda.fit(trainX, trainY)
ldaPredict = lda.predict(testX)
plt.stem(ldaPredict-testY)
plt.show()
# Out:
# D:\Programs\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:387: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")

# %%
trainY.shape
# Out:
# (1437,)

# %%
featTrainX = []
for x in range(len(trainX)):
    featTrainX.append(feature(trainX[x]))
# Out:
# 294.0
# 313.0
# 344.0
# 267.0
# 258.0
# 342.0
# 306.0
# 290.0
# 357.0
# 329.0
# 322.0
# 319.0
# 256.0
# 321.0
# 348.0
# 330.0
# 315.0
# 330.0
# 262.0
# 265.0
# 337.0
# 338.0
# 266.0
# 286.0
# 259.0
# 257.0
# 378.0
# 325.0
# 312.0
# 322.0
# 344.0
# 272.0
# 359.0
# 360.0
# 293.0
# 315.0
# 347.0
# 320.0
# 298.0
# 320.0
# 338.0
# 340.0
# 268.0
# 258.0
# 351.0
# 281.0
# 317.0
# 266.0
# 311.0
# 307.0
# 264.0
# 291.0
# 354.0
# 290.0
# 279.0
# 380.0
# 297.0
# 276.0
# 333.0
# 274.0
